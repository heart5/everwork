# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import *

# Fixing random state for reproducibility
np.random.seed(19680801)

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
import pathmagic
with pathmagic.context():
    from func.first import touchfilepath2depth, getdirmain, dirmainpath
    from work.zymessage import searchcustomer, searchqiankuan, searchpinxiang
    
print(getdirmain())
rstfile, rststr = searchqiankuan(['兴客隆', '汉阳'])
print(rststr)
linelist=rststr.split('\n')
print(linelist)
figure(figsize=(8,6), dpi=150)
for i in range(len(linelist)):
    plt.text(0.02, 0.9-i*0.07,linelist[i], fontsize=8, bbox=dict(facecolor='red', alpha=0.1))
plt.show()
# Out:
# ..
# 文件《全单统计管理最新.xlsm》已有 52 条记录，看是否最新？		无需更新。
# 输入参数：['兴客隆', '汉阳']
# 客户名称拆解：['兴客隆']
# 区域名称拆解：[]
# 分部名称拆解：['汉阳']
# 区域集合（数字）['33', '32', '31', '34']
# 客户编码查询结果：['32600020150SXXA', '32600520020SXXD']
# 找到2条记录
#                      单号             单位全名 送货金额   应收金额        送达日期  实收金额  收款日期
# 编码
# 3260002  2018-06-21-422  兴客隆超市 84799619*  300  -3758  2018-06-23   NaN  None
# 3260002  2019-07-22-668  兴客隆超市 84799619*  358    343  2019-07-24   NaN  None
# ['找到2条记录', '                     单号             单位全名 送货金额   应收金额        送达日期  实收金额  收款日期', '编码                                                                          ', '3260002  2018-06-21-422  兴客隆超市 84799619*  300  -3758  2018-06-23   NaN  None', '3260002  2019-07-22-668  兴客隆超市 84799619*  358    343  2019-07-24   NaN  None']
